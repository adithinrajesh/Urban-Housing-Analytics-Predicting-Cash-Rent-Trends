# %%
#Importing necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the csv files
contract_housing = pd.read_csv("contract housing rent.csv")

# %%
#Displaying first few rows to understand the data structure
contract_housing.head()
# Out:
#         Neighborhood  Id  Estimate contract housing; Total:  \
# 0   Allegheny Center   1                                798
# 1     Allegheny West   2                                 77
# 2          Allentown   3                                531
# 3          Arlington   4                                209
# 4  Arlington Heights   5                                144
#
#    Margin of Error contract housing; Total:  Estimate; With cash rent:  \
# 0                                 91.000000                        781
# 1                                 31.000000                         77
# 2                                138.166566                        481
# 3                                 70.562029                        204
# 4                                 59.000000                        140
#
#    Estimate; With cash rent: - Less than $100  \
# 0                                          23
# 1                                           0
# ...

# %%
#These are the column titles
print(contract_housing.columns)
# Out:
# Index(['Neighborhood', 'Id', 'Estimate contract housing; Total:',
#        'Margin of Error contract housing; Total:', 'Estimate; With cash rent:',
#        'Estimate; With cash rent: - Less than $100',
#        'Estimate; With cash rent: - $100 to $149',
#        'Estimate; With cash rent: - $150 to $199',
#        'Estimate; With cash rent: - $200 to $249',
#        'Estimate; With cash rent: - $250 to $299',
#        'Estimate; With cash rent: - $300 to $349',
#        'Estimate; With cash rent: - $350 to $399',
#        'Estimate; With cash rent: - $400 to $449',
#        'Estimate; With cash rent: - $450 to $499',
#        'Estimate; With cash rent: - $500 to $549',
#        'Estimate; With cash rent: - $550 to $599',
#        'Estimate; With cash rent: - $600 to $649',
#        'Estimate; With cash rent: - $650 to $699',
#        'Estimate; With cash rent: - $700 to $749',
#        'Estimate; With cash rent: - $750 to $799',
#        'Estimate; With cash rent: - $800 to $899',
# ...

# %%
#Dropping columns which are not required
columns_to_drop = [
    'Estimate; With cash rent: - Less than $100',
       'Estimate; With cash rent: - $100 to $149',
       'Estimate; With cash rent: - $150 to $199',
       'Estimate; With cash rent: - $200 to $249',
       'Estimate; With cash rent: - $250 to $299',
       'Estimate; With cash rent: - $300 to $349',
       'Estimate; With cash rent: - $350 to $399',
       'Estimate; With cash rent: - $400 to $449',
       'Estimate; With cash rent: - $450 to $499',
       'Estimate; With cash rent: - $500 to $549',
       'Estimate; With cash rent: - $550 to $599',
       'Estimate; With cash rent: - $600 to $649',
       'Estimate; With cash rent: - $650 to $699',
       'Estimate; With cash rent: - $700 to $749',
       'Estimate; With cash rent: - $750 to $799',
       'Estimate; With cash rent: - $800 to $899',
       'Estimate; With cash rent: - $900 to $999',
       'Estimate; With cash rent: - $1,000 to $1,249',
       'Estimate; With cash rent: - $1,250 to $1,499',
       'Estimate; With cash rent: - $1,500 to $1,999',
       'Estimate; With cash rent: - $2,000 to $2,499',
       'Estimate; With cash rent: - $2,500 to $2,999',
       'Estimate; With cash rent: - $3,000 to $3,499',
       'Estimate; With cash rent: - $3,500 or more', 
]

# Drop the specified columns
contract_housing1 = contract_housing.drop(columns=columns_to_drop)

# %%
# %store -r contract_housing1

# %%
#The data types of each column
print(contract_housing1.dtypes)
# Out:
# Neighborhood                  object
# Id                             int64
# Estimate; Total:               int64
# Margin of Error; Total:      float64
# Estimate; With cash rent:      int64
# Estimate; No cash rent         int64
# Low rent                       int64
# Mid rent                       int64
# High rent                      int64
# Total rent                     int64
# No cash rent                   int64
# dtype: object

# %%
#Getting a description of the data
contract_housing1.describe()
# Out:
#              Id  Estimate; Total:  Margin of Error; Total:  \
# count  91.00000         91.000000                91.000000
# mean   46.00000        766.142857               118.220820
# std    26.41338        864.205628                70.625872
# min     1.00000          0.000000                 5.000000
# 25%    23.50000        207.500000                61.500000
# 50%    46.00000        556.000000               111.772090
# 75%    68.50000        917.000000               153.364908
# max    91.00000       5548.000000               347.223271
#
#        Estimate; With cash rent:  Estimate; No cash rent    Low rent  \
# count                  91.000000               91.000000   91.000000
# mean                  741.912088               24.230769  159.054945
# std                   844.497203               29.342452  139.677992
# min                     0.000000                0.000000    0.000000
# 25%                   199.500000                0.000000   40.000000
# ...

# %%
#Plotting a combined bar graph
rent_columns = ['Low rent', 'Mid rent', 'High rent']
plt.figure(figsize=(15, 8))
ax = contract_housing1[rent_columns].plot(kind='bar', stacked=True, width=0.8)
plt.xlabel('Id')
plt.ylabel('Rent Categories')
plt.title('Rent Categories by Neighborhood')
plt.legend(title='Rent Category')

# Rotate and display every 5th label
for i, label in enumerate(ax.get_xticklabels()):
    if i % 5 != 0:
        label.set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Plotting a combined bar graph
grouped_data = contract_housing1.reset_index()
plt.figure(figsize=(15, 8))

rent_columns = ['Low rent', 'Mid rent', 'High rent']

for rent_category in rent_columns:
    sns.barplot(x='Neighborhood', 
                y=rent_category, 
                data=grouped_data, 
                label=rent_category)

plt.xlabel('Neighborhood')
plt.ylabel('Count')
plt.title('Comparison of Rent Categories Across Neighborhoods')
plt.legend(loc='upper right')

plt.xticks(rotation=45, ha='right')
plt.xticks(fontsize=8)

plt.tight_layout()
plt.show()

# %%
#Plotting a bar graph
plt.figure(figsize=(15, 8))
sns.barplot(x='Neighborhood', y='Total rent', data=contract_housing1, ci=None)
plt.xlabel('Neighborhood')
plt.ylabel('Average Total Rent')
plt.title('Average Total Rent Across Neighborhoods')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/b8/j_gf4x196c1ch2_p5wh4jzj40000gn/T/ipykernel_60851/1584270734.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Neighborhood', y='Total rent', data=contract_housing1, ci=None)

# %%
#Plotting a correlation matrix
correlation_matrix = contract_housing1[['Estimate; No cash rent', 'Estimate; With cash rent:', 'Total rent', 'Margin of Error; Total:']].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap for Rent Variables')
plt.show()

# %%
#Checking the number of missing values in each columns
missing_values = contract_housing1.isnull().sum()
print(missing_values)
# Out:
# Neighborhood                 0
# Id                           0
# Estimate; Total:             0
# Margin of Error; Total:      0
# Estimate; With cash rent:    0
# Estimate; No cash rent       0
# Low rent                     0
# Mid rent                     0
# High rent                    0
# Total rent                   0
# No cash rent                 0
# dtype: int64

# %%
#Determining the unique values in the neighborhood
print(contract_housing1['Neighborhood'].unique())
# Out:
# ['Allegheny Center' 'Allegheny West' 'Allentown' 'Arlington'
#  'Arlington Heights' 'Banksville' 'Bedford Dwellings' 'Beechview'
#  'Beltzhoover' 'Bloomfield' 'Bluff' 'Bon Air' 'Brighton Heights'
#  'Brookline' 'California-Kirkbride' 'Carrick' 'Central Business District'
#  'Central Lawrenceville' 'Central Northside' 'Central Oakland'
#  'Chartiers City' 'Chateau' 'Crafton Heights' 'Crawford-Roberts'
#  'Duquesne Heights' 'East Allegheny' 'East Carnegie' 'East Hills'
#  'East Liberty' 'Elliott' 'Esplen' 'Fairywood' 'Fineview' 'Friendship'
#  'Garfield' 'Glen Hazel' 'Greenfield' 'Hays' 'Hazelwood' 'Highland Park'
#  'Homewood North' 'Homewood South' 'Homewood West' 'Knoxville' 'Larimer'
#  'Lincoln Place' 'Lincoln-Lemington-Belmar' 'Lower Lawrenceville'
#  'Manchester' 'Marshall-Shadeland' 'Middle Hill' 'Morningside'
#  'Mount Oliver Borough' 'Mount Washington' 'Mt. Oliver' 'New Homestead'
#  'North Oakland' 'North Shore' 'Northview Heights' 'Oakwood' 'Overbrook'
# ...

# %%
#Performing one hot encoding, feature engineering for neighborhood columns
one_hot_encoded = pd.get_dummies(contract_housing1['Neighborhood'], prefix='neighborhood')
contract_housing2 = pd.concat([contract_housing1, one_hot_encoded], axis=1)

# %%
contract_housing2.head()
# Out:
#         Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 0   Allegheny Center   1               798                91.000000
# 1     Allegheny West   2                77                31.000000
# 2          Allentown   3               531               138.166566
# 3          Arlington   4               209                70.562029
# 4  Arlington Heights   5               144                59.000000
#
#    Estimate; With cash rent:  Estimate; No cash rent  Low rent  Mid rent  \
# 0                        781                      17       133       355
# 1                         77                       0         3        48
# 2                        481                      50       217       235
# 3                        204                       5        14       172
# 4                        140                       4        98        42
#
#    High rent  Total rent  ...  neighborhood_Summer Hill  \
# 0        293         781  ...                     False
# ...
